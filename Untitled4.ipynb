# %%
import hyperspy.api as hp

# %%
s = hp.load("EELS Spectrum Image 16x16 1s 0.5eV 78offset.dm3")
# Out:
# WARNING:hyperspy.signal:<EELSSpectrum, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (16, 16|1024)> data is replaced by its optimized copy

# %%
s.plot()

# %%
s
# Out:
# <EELSSpectrum, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (16, 16|1024)>

# %%
Sp = s.isig[1].data

# %%
s.isig[1]
# Out:
# <BaseSignal, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (16, 16|)>

# %%
Sp.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-3a71c5da7779> in <module>()
# ----> 1 Sp.plot()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
s.inav[0,0]
# Out:
# <EELSSpectrum, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (|1024)>

# %%
Sp.inav[0,0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-0802ad3f5e3a> in <module>()
# ----> 1 Sp.inav[0,0]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'inav'

# %%
Sp = s.inav[0,0];

# %%
Sp
# Out:
# <EELSSpectrum, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (|1024)>

# %%
Sp.plot()

# %%
Sp = s.inav[1,1];

# %%
Sp.plot()

# %%
SSD = Sp.remove_background(signal_range=(50,98),background_type='PowerLaw')

# %%
SSD.plot()

# %%
import numpy as np

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
s.set_signal_type("EELS")

# %%
Sp = s.inav[1,10]

# %%
SSD = Sp.remove_background(signal_range=(60,98),background_type='PowerLaw')

# %%
SSD
# Out:
# <EELSSpectrum, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (|1024)>

# %%
# %matplotlib inline

# %%
SSD.plot()

# %%
s = hp.load("LL_cal.msa")

# %%
s.plot()

# %%
SSD_s = s.fourier_log_deconvolution(s,True,True)

# %%
SSD_s.plot()

# %%
s = hp.load("EELS Spectrum Image 16x16 1s 0.5eV 78offset.dm3")
# Out:
# WARNING:hyperspy.signal:<EELSSpectrum, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (16, 16|1024)> data is replaced by its optimized copy

# %%
s.set_signal_type("EELS")

# %%
s.set_microscope_parameters(197,9.5,16)

# %%
s.add_elements(('Si'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-f72a5a50dfe6> in <module>()
# ----> 1 s.add_elements(('Si'))
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/_signals/eels.py in add_elements(self, elements, include_pre_edges)
#      86         if not isiterable(elements) or isinstance(elements, str):
#      87             raise ValueError(
# ---> 88                 "Input must be in the form of a tuple. For example, "
#      89                 "if `s` is the variable containing this EELS spectrum:\n "
#      90                 ">>> s.add_elements(('C',))\n"
#
# ValueError: Input must be in the form of a tuple. For example, if `s` is the variable containing this EELS spectrum:
#  >>> s.add_elements(('C',))
# See the docstring for more information.

# %%
Sp
# Out:
# <EELSSpectrum, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (|1024)>

# %%
Sp.set_signal_type("EELS")

# %%
Sp.add_elements(('Si'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-aece87fc32d1> in <module>()
# ----> 1 Sp.add_elements(('Si'))
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/_signals/eels.py in add_elements(self, elements, include_pre_edges)
#      86         if not isiterable(elements) or isinstance(elements, str):
#      87             raise ValueError(
# ---> 88                 "Input must be in the form of a tuple. For example, "
#      89                 "if `s` is the variable containing this EELS spectrum:\n "
#      90                 ">>> s.add_elements(('C',))\n"
#
# ValueError: Input must be in the form of a tuple. For example, if `s` is the variable containing this EELS spectrum:
#  >>> s.add_elements(('C',))
# See the docstring for more information.

# %%
s = hp.load("LL_cal.msa")

# %%
s.add_elements(('Si'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-f72a5a50dfe6> in <module>()
# ----> 1 s.add_elements(('Si'))
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/_signals/eels.py in add_elements(self, elements, include_pre_edges)
#      86         if not isiterable(elements) or isinstance(elements, str):
#      87             raise ValueError(
# ---> 88                 "Input must be in the form of a tuple. For example, "
#      89                 "if `s` is the variable containing this EELS spectrum:\n "
#      90                 ">>> s.add_elements(('C',))\n"
#
# ValueError: Input must be in the form of a tuple. For example, if `s` is the variable containing this EELS spectrum:
#  >>> s.add_elements(('C',))
# See the docstring for more information.

# %%
s.set_microscope_parameters(200,0.2,2.55)

# %%
s.add_elements(('Si','O'))

# %%
Sp = s.inav[10,10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-28583ade69eb> in <module>()
# ----> 1 Sp = s.inav[10,10]
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/misc/slicing.py in __getitem__(self, slices, out)
#     143
#     144     def __getitem__(self, slices, out=None):
# --> 145         return self.obj._slicer(slices, self.isNavigation, out=out)
#     146
#     147
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/misc/slicing.py in _slicer(self, slices, isNavigation, out)
#     207
#     208     def _slicer(self, slices, isNavigation=None, out=None):
# --> 209         array_slices = self._get_array_slices(slices, isNavigation)
#     210         if out is None:
#     211             _obj = self._deepcopy_with_new_data(self.data[array_slices],
#
# ...

# %%
s = hp.load("EELS Spectrum Image 16x16 1s 0.5eV 78offset.dm3")
# Out:
# WARNING:hyperspy.signal:<EELSSpectrum, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (16, 16|1024)> data is replaced by its optimized copy

# %%
Sp = s.inav[10,10]

# %%
Sp.add_elements(('Si','O'))

# %%
create_model()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-d35f9d1647a4> in <module>()
# ----> 1 create_model()
#
# NameError: name 'create_model' is not defined

# %%
m = s.create_model()

# %%
m.components
# Out:
#    # |      Attribute Name |      Component Name |      Component Type
# ---- | ------------------- | ------------------- | -------------------
#    0 |            PowerLaw |            PowerLaw |            PowerLaw

# %%
m.enable_fine_structure()

# %%
m.smart_fit()
# Out:
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/_components/power_law.py:68: RuntimeWarning: overflow encountered in power
#   (x - self.origin.value) ** (-self.r.value), 0)
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/_components/power_law.py:68: RuntimeWarning: overflow encountered in multiply
#   (x - self.origin.value) ** (-self.r.value), 0)

# %%
m.multifit(kind='smart')
# Out:
# 100%|██████████| 256/256 [00:01<00:00, 227.17it/s]

# %%
m.plot()

# %%
Sp
# Out:
# <EELSSpectrum, title: EELS Spectrum Image 16x16 1s 0.5eV 78offset, dimensions: (|1024)>

# %%
Sp.add_elements(('Si', 'B'))

# %%
m = Sp.create_model()

# %%
m.enable_fine_structure()

# %%
m.smart_fit()

# %%
m.multifit(kind='smart')

# %%
m.components
# Out:
#    # |      Attribute Name |      Component Name |      Component Type
# ---- | ------------------- | ------------------- | -------------------
#    0 |            PowerLaw |            PowerLaw |            PowerLaw
#    1 |               Si_L3 |               Si_L3 |          EELSCLEdge
#    2 |                 O_K |                 O_K |          EELSCLEdge
#    3 |                 B_K |                 B_K |          EELSCLEdge

# %%
m.plot()

# %%
m.quantify()
# Out:
# Absolute quantification:
# Elem.	Intensity
# Si	5.457809
# B	6.386153
# O	1.000000

# %%
import matplotlib

# %%
m.plot()

# %%
import matplotlib.pyplot

# %%
m.plot()

# %%
from pylab import *

# %%
m.plot()

# %%
from matplotlib import interactive

# %%
interactive(True)

# %%
m.plot()

# %%
# %matplotlib qt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-117-f713c27910c9> in <module>()
# ----> 1 get_ipython().magic('matplotlib qt')
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
# ...

# %%
# %matplotlib qt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-119-f713c27910c9> in <module>()
# ----> 1 get_ipython().magic('matplotlib qt')
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
# ...

# %%
close all
# Out:
#   File "<ipython-input-120-c2bf6236b4ff>", line 1
#     close all
#             ^
# SyntaxError: invalid syntax

# %%
s = hp.load("//users//veersaysit//Desktop//EELS data//AlNTb-P14-800degree//EELS Spectrum Image1.dm3")
# Out:
# WARNING:hyperspy.signal:<EELSSpectrum, title: EELS Spectrum Image1, dimensions: (100, 87|512)> data is replaced by its optimized copy

# %%
# %matplotlib inline

# %%
s.plot()

# %%
s.add_elements(('N','O','Tb'))

# %%
ll = hp.load("//users//veersaysit//Desktop//EELS data//AlNTb-P14-800degree//EELS Spectrum Image1-thickness-map.dm3")
# Out:
# WARNING:hyperspy.signal:<EELSSpectrum, title: EELS Spectrum Image1-thickness-map, dimensions: (100, 87|2048)> data is replaced by its optimized copy

# %%
m = s.create_model(ll=ll)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-5826a84d3cc6> in <module>()
# ----> 1 m = s.create_model(ll=ll)
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/_signals/eels.py in create_model(self, ll, auto_background, auto_add_edges, GOS, dictionary)
#    1252                           auto_add_edges=auto_add_edges,
#    1253                           GOS=GOS,
# -> 1254                           dictionary=dictionary)
#    1255         return model
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/models/eelsmodel.py in __init__(self, signal1D, auto_background, auto_add_edges, ll, GOS, dictionary)
#      91
#      92         if self.signal.subshells and auto_add_edges is True:
# ---> 93             self._add_edges_from_subshells_names()
#      94
#      95     @property
#
# ...

# %%
L = ll.inav[10,10];

# %%
m = s.create_model(ll=L)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-ca9a85dc0cc1> in <module>()
# ----> 1 m = s.create_model(ll=L)
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/_signals/eels.py in create_model(self, ll, auto_background, auto_add_edges, GOS, dictionary)
#    1252                           auto_add_edges=auto_add_edges,
#    1253                           GOS=GOS,
# -> 1254                           dictionary=dictionary)
#    1255         return model
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/models/eelsmodel.py in __init__(self, signal1D, auto_background, auto_add_edges, ll, GOS, dictionary)
#      77         self._suspend_auto_fine_structure_width = False
#      78         self.convolved = False
# ---> 79         self.low_loss = ll
#      80         self.GOS = GOS
#      81         self.edges = []
#
# ...

# %%
m = s.create_model()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-23a6348573b8> in <module>()
# ----> 1 m = s.create_model()
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/_signals/eels.py in create_model(self, ll, auto_background, auto_add_edges, GOS, dictionary)
#    1252                           auto_add_edges=auto_add_edges,
#    1253                           GOS=GOS,
# -> 1254                           dictionary=dictionary)
#    1255         return model
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/models/eelsmodel.py in __init__(self, signal1D, auto_background, auto_add_edges, ll, GOS, dictionary)
#      91
#      92         if self.signal.subshells and auto_add_edges is True:
# ---> 93             self._add_edges_from_subshells_names()
#      94
#      95     @property
#
# ...

# %%
m1 = s.create_model()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-709851efdb51> in <module>()
# ----> 1 m1 = s.create_model()
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/_signals/eels.py in create_model(self, ll, auto_background, auto_add_edges, GOS, dictionary)
#    1252                           auto_add_edges=auto_add_edges,
#    1253                           GOS=GOS,
# -> 1254                           dictionary=dictionary)
#    1255         return model
#
# /Users/veersaysit/anaconda/lib/python3.6/site-packages/hyperspy/models/eelsmodel.py in __init__(self, signal1D, auto_background, auto_add_edges, ll, GOS, dictionary)
#      91
#      92         if self.signal.subshells and auto_add_edges is True:
# ---> 93             self._add_edges_from_subshells_names()
#      94
#      95     @property
#
# ...
