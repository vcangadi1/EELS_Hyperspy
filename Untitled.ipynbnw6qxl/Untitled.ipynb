# %%
import hyperspy.api as hs

# %%
fileID = open("S.txt","r")

# %%
print fileID
# Out:
# <open file 'S.txt', mode 'r' at 0x000000001AB246F0>

# %%
print fileID.read()
# Out:
# 851.00 2259.70960000
# 852.00 2226.03920000
# 853.00 2238.23840000
# 854.00 2210.08160000
# 855.00 2219.54160000
# 856.00 2208.79200000
# 857.00 2198.00320000
# 858.00 2181.72880000
# 859.00 2202.76560000
# 860.00 2177.66480000
# 861.00 2182.52480000
# 862.00 2159.32320000
# 863.00 2168.98240000
# 864.00 2158.06400000
# 865.00 2145.34240000
# 866.00 2141.39360000
# 867.00 2124.43120000
# 868.00 2123.75040000
# 869.00 2097.02480000
# 870.00 2118.07600000
# 871.00 2101.90720000
# 872.00 2099.00240000
# 873.00 2087.06880000
# 874.00 2066.26320000
# 875.00 2056.60080000
# 876.00 2055.33360000
# 877.00 2052.18720000
# 878.00 2060.30960000
# 879.00 2051.38320000
# 880.00 2042.09920000
# 881.00 2034.67280000
# 882.00 2032.92720000
# 883.00 2022.61840000
# 884.00 2015.96640000
# 885.00 1995.74880000
# 886.00 1994.34880000
# 887.00 1970.18560000
# 888.00 1960.44720000
# 889.00 1980.38240000
# 890.00 1982.54240000
# 891.00 1954.62960000
# 892.00 1943.12480000
# 893.00 1960.02640000
# ...

# %%
with open('S.txt','r')
