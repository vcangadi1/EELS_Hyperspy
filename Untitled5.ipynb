# %%
import hyperspy.api as hp
# Out:
# Logging is active
# The log is stored in the hyperspy_log.py file in the current directory
# WARNING:hyperspy.api:The traitsui GUI elements are not available, probably because the hyperspy_gui_traitui package is not installed.

# %%
# %matplotlib qt5

# %%
S = hp.datasets.eelsdb(formula="GaAs")

# %%
S
# Out:
# [<EELSSpectrum, title: Gallium Arsenide, dimensions: (|920)>,
#  <EELSSpectrum, title: Gallium Arsenide, dimensions: (|980)>]

# %%
S[1]
# Out:
# <EELSSpectrum, title: Gallium Arsenide, dimensions: (|980)>

# %%
S[1].plot()
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
S[1]
# Out:
# <EELSSpectrum, title: Gallium Arsenide, dimensions: (|980)>

# %%
S[1].data
# Out:
# array([  3.42000000e+02,   6.07000000e+02,   4.86000000e+02,
#          2.54000000e+02,   3.08000000e+02,   3.45999900e+02,
#          4.68000000e+02,   5.25000000e+02,   4.75999900e+02,
#          4.81000000e+02,   3.99000100e+02,   4.15000100e+02,
#          3.93000100e+02,   5.54999900e+02,   6.05999900e+02,
#          5.12999900e+02,   5.80000100e+02,   7.17999800e+02,
#          7.04000100e+02,   6.84000400e+02,   7.87999600e+02,
#          6.17000300e+02,   8.12999700e+02,   8.52000300e+02,
#          8.86999700e+02,   1.11500000e+03,   1.02200000e+03,
#          1.09900000e+03,   9.13000400e+02,   1.03600000e+03,
#          1.18500000e+03,   1.24500000e+03,   1.56999900e+03,
#          1.37800000e+03,   1.70900000e+03,   1.53400000e+03,
#          1.72700000e+03,   1.77200000e+03,   1.91200000e+03,
#          1.95200000e+03,   2.12300000e+03,   2.21400000e+03,
#          2.64500000e+03,   2.98899900e+03,   3.08100100e+03,
# ...

# %%
S
# Out:
# [<EELSSpectrum, title: Gallium Arsenide, dimensions: (|920)>,
#  <EELSSpectrum, title: Gallium Arsenide, dimensions: (|980)>]

# %%
S[-1]
# Out:
# <EELSSpectrum, title: Gallium Arsenide, dimensions: (|980)>

# %%
S[0]
# Out:
# <EELSSpectrum, title: Gallium Arsenide, dimensions: (|920)>

# %%
S[1].plot()
